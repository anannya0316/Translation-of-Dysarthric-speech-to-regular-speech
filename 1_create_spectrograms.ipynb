# %% [markdown]
# ##### This script creates spectrogram matrices from wav files
#
# It successfully converted almost all of the .wav files except for a few corrupted files. It was also not able to convert the files from M01 Session 1 headMic, due to some type of end of file issue.
#
# Leveraged the [following code](https://github.com/kykiefer/depression-detect/blob/master/src/features/spectrograms.py), and made edits where needed.

# %%
# Import packages

import numpy as np
from numpy.lib import stride_tricks
import os
from PIL import Image
import scipy.io.wavfile as wav

# %%
# Location of source .wav files to convert. Each session has two recordings from two different microphones.

dir_names = ['data/TORGO/F01/Session1',
            'data/TORGO/F03/Session1','data/TORGO/F03/Session2','data/TORGO/F03/Session3',
            'data/TORGO/F04/Session1','data/TORGO/F04/Session2',
            'data/TORGO/M01/Session1','data/TORGO/M01/Session2_3',
            'data/TORGO/M02/Session1','data/TORGO/M02/Session2',
            'data/TORGO/M03/Session2',
            'data/TORGO/M04/Session1','data/TORGO/M04/Session2',
            'data/TORGO/M05/Session1','data/TORGO/M05/Session2']
mics = ['wav_headMic','wav_arrayMic']

# %%
# Functions for processing

def stft(sig, frameSize, overlapFac=0.5, window=np.hanning):
    """
    Short-time Fourier transform of audio signal.
    """
    win = window(frameSize)
    hopSize = int(frameSize - np.floor(overlapFac * frameSize).astype(int))
    # zeros at beginning (thus center of 1st window should be for sample nr. 0)
    samples = np.append(np.zeros(np.floor(frameSize/2.0).astype(int)), sig)
    # cols for windowing
    cols = np.ceil((len(samples) - frameSize) / float(hopSize)).astype(int) + 1
    # zeros at end (thus samples can be fully covered by frames)
    samples = np.append(samples, np.zeros(frameSize))

    frames = stride_tricks.as_strided(samples, shape=(cols, frameSize),
                                      strides=(samples.strides[0]*hopSize,
                                      samples.strides[0])).copy()
    frames *= win

    return np.fft.rfft(frames)


def logscale_spec(spec, sr=44100, factor=20.):
    """
    Scale frequency axis logarithmically.
    """
    timebins, freqbins = np.shape(spec)
    
    scale = np.linspace(0, 1, freqbins) ** factor
    scale *= (freqbins-1)/max(scale)
    scale = np.unique(np.round(scale)).astype(int)
  
    # create spectrogram with new freq bins
    newspec = np.complex128(np.zeros([timebins, len(scale)]))
    for i in range(0, len(scale)):
        if i == len(scale)-1:
            newspec[:, i] = np.sum(spec[:, scale[i]:], axis=1)
        else:
            newspec[:, i] = np.sum(spec[:, scale[i]:scale[i+1]], axis=1)

    # list center freq of bins
    allfreqs = np.abs(np.fft.fftfreq(freqbins*2, 1./sr)[:freqbins+1])
    freqs = []
    for i in range(0, len(scale)):
        if i == len(scale)-1:
            freqs += [np.mean(allfreqs[scale[i]:])]
        else:
            freqs += [np.mean(allfreqs[scale[i]:scale[i+1]])]

    return newspec, freqs


def stft_matrix(audiopath, binsize=2**10, png_name='tmp.png',
                save_png=False, offset=0):
    """
    A function that converts a wav file into a spectrogram represented by a \
    matrix where rows represent frequency bins, columns represent time, and \
    the values of the matrix represent the decibel intensity. A matrix of \
    this form can be passed as input to the CNN after undergoing normalization.
    """
    samplerate, samples = wav.read(audiopath)
    s = stft(samples, binsize)

    sshow, freq = logscale_spec(s, factor=1, sr=samplerate)
    ims = 20.*np.log10(np.abs(sshow)/10e-6)  # amplitude to decibel
    timebins, freqbins = np.shape(ims)

    ims = np.transpose(ims)
    ims = np.flipud(ims)

    if save_png:
        create_png(ims, png_name)

    return ims


def create_png(im_matrix, png_name):
    """
    Save grayscale png of spectrogram.
    """
    image = Image.fromarray(im_matrix)
    image = image.convert('L')  # convert to grayscale
    image.save(png_name)

# %%
# Convert files

for d in dir_names:
    for m in mics:
        dir_name = d + '/' + m
        print('Processing directory' + dir_name + '...')
        if not os.path.exists(dir_name + '_spect/'):
            os.makedirs(dir_name + '_spect/')
        for subdir, dirs, files in os.walk(dir_name):
            for file in files:
                if file.endswith('.wav'):
                    wav_file = os.path.join(subdir, file)
                    png_name = subdir + '_spect/' + file[:-4] + '.png'
                    try:
                        stft_matrix(wav_file, png_name=png_name, save_png=True)
                    except:
                        print('WARNING: Unable to convert ' + file)
                        pass

print("Spectrogram Conversion Complete!")
# Out:
# Processing directorydata/TORGO/F01/Session1/wav_headMic...
# WARNING: Unable to convert 0067.wav
# WARNING: Unable to convert 0068.wav
# Processing directorydata/TORGO/F01/Session1/wav_arrayMic...
# Processing directorydata/TORGO/F03/Session1/wav_headMic...
# Processing directorydata/TORGO/F03/Session1/wav_arrayMic...
# Processing directorydata/TORGO/F03/Session2/wav_headMic...
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 154124 bytes, expected 154132 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# Processing directorydata/TORGO/F03/Session2/wav_arrayMic...
# Processing directorydata/TORGO/F03/Session3/wav_headMic...
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 88044 bytes, expected 88052 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# Processing directorydata/TORGO/F03/Session3/wav_arrayMic...
# Processing directorydata/TORGO/F04/Session1/wav_headMic...
# Processing directorydata/TORGO/F04/Session1/wav_arrayMic...
# Processing directorydata/TORGO/F04/Session2/wav_headMic...
# Processing directorydata/TORGO/F04/Session2/wav_arrayMic...
# Processing directorydata/TORGO/M01/Session1/wav_headMic...
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 304684 bytes, expected 304692 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 237484 bytes, expected 237492 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 252524 bytes, expected 252532 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 210444 bytes, expected 210452 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 386446 bytes, expected 386454 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 91564 bytes, expected 91572 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 83884 bytes, expected 83892 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 129964 bytes, expected 129972 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 273324 bytes, expected 273332 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 123564 bytes, expected 123572 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 302764 bytes, expected 302772 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 327244 bytes, expected 327252 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 253324 bytes, expected 253332 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 88364 bytes, expected 88372 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 121164 bytes, expected 121172 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 113164 bytes, expected 113172 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 94444 bytes, expected 94452 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 290766 bytes, expected 290774 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 396524 bytes, expected 396532 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 112364 bytes, expected 112372 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 118124 bytes, expected 118132 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 108684 bytes, expected 108692 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 169484 bytes, expected 169492 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 103084 bytes, expected 103092 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 100044 bytes, expected 100052 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 302124 bytes, expected 302132 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 140044 bytes, expected 140052 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 155244 bytes, expected 155252 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 92524 bytes, expected 92532 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 122604 bytes, expected 122612 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 90924 bytes, expected 90932 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 129484 bytes, expected 129492 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 113004 bytes, expected 113012 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 109644 bytes, expected 109652 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 109006 bytes, expected 109014 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 105644 bytes, expected 105652 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 150924 bytes, expected 150932 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 120524 bytes, expected 120532 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 243404 bytes, expected 243412 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 229324 bytes, expected 229332 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 329164 bytes, expected 329172 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 218924 bytes, expected 218932 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 289804 bytes, expected 289812 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 132686 bytes, expected 132694 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 127564 bytes, expected 127572 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 92364 bytes, expected 92372 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 120046 bytes, expected 120054 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 107724 bytes, expected 107732 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 126126 bytes, expected 126134 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 98284 bytes, expected 98292 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 105966 bytes, expected 105974 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 251884 bytes, expected 251892 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 99084 bytes, expected 99092 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 109164 bytes, expected 109172 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 397964 bytes, expected 397972 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 125164 bytes, expected 125172 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 137326 bytes, expected 137334 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 98764 bytes, expected 98772 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 156204 bytes, expected 156212 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 110444 bytes, expected 110452 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 215564 bytes, expected 215572 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 131084 bytes, expected 131092 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 144524 bytes, expected 144532 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 251726 bytes, expected 251734 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 132364 bytes, expected 132372 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 116524 bytes, expected 116532 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 106604 bytes, expected 106612 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 97966 bytes, expected 97974 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 117004 bytes, expected 117012 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 329166 bytes, expected 329174 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 105164 bytes, expected 105172 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 113324 bytes, expected 113332 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 95726 bytes, expected 95734 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 292364 bytes, expected 292372 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 130284 bytes, expected 130292 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 97004 bytes, expected 97012 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 91244 bytes, expected 91252 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 123244 bytes, expected 123252 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 481004 bytes, expected 481012 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 102124 bytes, expected 102132 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 117484 bytes, expected 117492 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 97644 bytes, expected 97652 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 110766 bytes, expected 110774 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 145484 bytes, expected 145492 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 129004 bytes, expected 129012 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 105964 bytes, expected 105972 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 326284 bytes, expected 326292 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 101324 bytes, expected 101332 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 98126 bytes, expected 98134 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 78444 bytes, expected 78452 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 93966 bytes, expected 93974 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 102284 bytes, expected 102292 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# Processing directorydata/TORGO/M01/Session1/wav_arrayMic...
# Processing directorydata/TORGO/M01/Session2_3/wav_headMic...
# Processing directorydata/TORGO/M01/Session2_3/wav_arrayMic...
# Processing directorydata/TORGO/M02/Session1/wav_headMic...
# Processing directorydata/TORGO/M02/Session1/wav_arrayMic...
# Processing directorydata/TORGO/M02/Session2/wav_headMic...
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 61644 bytes, expected 61652 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 62924 bytes, expected 62932 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# Processing directorydata/TORGO/M02/Session2/wav_arrayMic...
# Processing directorydata/TORGO/M03/Session2/wav_headMic...
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 76204 bytes, expected 76212 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 189324 bytes, expected 189332 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 99244 bytes, expected 99252 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# Processing directorydata/TORGO/M03/Session2/wav_arrayMic...
# Processing directorydata/TORGO/M04/Session1/wav_headMic...
# Processing directorydata/TORGO/M04/Session1/wav_arrayMic...
# Processing directorydata/TORGO/M04/Session2/wav_headMic...
# Processing directorydata/TORGO/M04/Session2/wav_arrayMic...
# WARNING: Unable to convert .wav
# Processing directorydata/TORGO/M05/Session1/wav_headMic...
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 99404 bytes, expected 99412 bytes from header.
#   samplerate, samples = wav.read(audiopath)
# Processing directorydata/TORGO/M05/Session1/wav_arrayMic...
# Processing directorydata/TORGO/M05/Session2/wav_headMic...
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:66: RuntimeWarning: divide by zero encountered in log10
#   ims = 20.*np.log10(np.abs(sshow)/10e-6)  # amplitude to decibel
# Processing directorydata/TORGO/M05/Session2/wav_arrayMic...
# Spectrogram Conversion Complete!
# C:\Users\anann\AppData\Local\Temp\ipykernel_3252\1226677615.py:62: WavFileWarning: Reached EOF prematurely; finished at 174124 bytes, expected 174132 bytes from header.
#   samplerate, samples = wav.read(audiopath)
